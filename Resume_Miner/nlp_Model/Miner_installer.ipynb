# %%
# %pip install pyresparser
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#       --------------------------------------- 0.1/4.2 MB 1.1 MB/s eta 0:00:04
#      -- ------------------------------------- 0.3/4.2 MB 3.8 MB/s eta 0:00:02
#      ------- -------------------------------- 0.8/4.2 MB 6.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 1.2/4.2 MB 8.6 MB/s eta 0:00:01
#      ---------------- ----------------------- 1.8/4.2 MB 9.5 MB/s eta 0:00:01
#      --------------------- ------------------ 2.3/4.2 MB 10.4 MB/s eta 0:00:01
#      ----------------------- ---------------- 2.5/4.2 MB 10.0 MB/s eta 0:00:01
#      ----------------------- ---------------- 2.5/4.2 MB 8.4 MB/s eta 0:00:01
#      ------------------------ --------------- 2.6/4.2 MB 7.8 MB/s eta 0:00:01
#      ------------------------- -------------- 2.7/4.2 MB 7.5 MB/s eta 0:00:01
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
# ...

# %%
# %pip install pdfminer3
